# %% [markdown]
# # Sales Analysis using SQL
#
#     In this project I analyse the sales of a retail store in the business of selling corporate, home office and consumer products. The store has a reach in  regions Central, West, East and South where there are Managers taking care of business in these regions. The business ships to its diverse customers by means of 2 modes of delivery, air and road. By road the business delivers by means of a delivery truck and by air they have defined the mode shipping into 2 thus regular air and express air.
#
#
# ### Objective
#
#     The objective of the Sales Analysis in SQL is to extract insights about thier operations in terms of shipping costs, profit and discounts as well as the returns of products. These insights will help determine the most lucrative business model, viable mode of delivery and areas of business improvements through regional contribution to the total business. Many other questions relating to Sales Analysis will be answered in the Project. In this project I will be using SQL language to analyze the data in SQL Server. The data has three tables that will be defined in the next sections

# %% [markdown]
# ### Database Schema

# %% [markdown]
# ![image.png](attachment:7f54c565-823c-4bd2-ad8e-76cad0086bbe.png)

# %% [markdown]
#     The table above shows us that the 3 tables are related on a one to one basis relationships and the column definitions for all the 3 tables is explained in the next section.

# %% [markdown]
# ### Table column definitions

# %% [markdown]
# ![image.png](attachment:9c9fc728-feae-4703-be55-8125fb954d26.png)

# %% [markdown]
# <br>

# %% [markdown]
# ![image.png](attachment:1f7b7dcc-868d-4eaa-b44e-614a8ae48552.png)

# %% [markdown]
# <br>

# %% [markdown]
# ![image.png](attachment:1a6b3c00-597a-4ce2-816b-66a5240e7598.png)

# %% [markdown]
# <br>

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ### 1. Table Datatypes

# %% [markdown]
#     We start off by viewing the data types of the tables in the Sales database.
#
#     1. Orders Table Data Types

# %% [markdown]
# ![image.png](attachment:f271430e-2da0-4a8f-b160-e8856ab236b6.png)

# %% [markdown]
#     2. Returns Table Data Types
#
# ![image.png](attachment:375229e7-54b0-433b-a1e9-e7d17749fbd1.png)
#
#     The Users table datatypes are nvarchar data types since they are strings thus names of regions and Managers

# %% [markdown]
# <br>

# %% [markdown]
# ### 2. Viewing the data

# %% [markdown]
#     Viewing a sample of the data that we will be working with.
#
#     Below is the top 5 rows from the Orders data

# %% [markdown]
# ![image.png](attachment:3a17c6ee-339b-4802-934c-6875f3dd96b5.png)

# %% [markdown]
#     Now viewing the top 5 rows of the Returns
#
# ![image.png](attachment:8046d04a-8a02-4e38-b646-fdfe7d9f3866.png)

# %% [markdown]
#     Viewing the top 5 rows of the Users
#
# ![image.png](attachment:c40e885d-5e6a-4784-bb0b-cdd792a0fbd4.png)

# %% [markdown]
#     From the Users table we can note that the row number 1 should be promoted to headers so that we have row 1 as the headers to the table. The error might have occured when the data was loaded into the SQL Server from a csv file.

# %% [markdown]
# ![image.png](attachment:2bab33e2-8a45-4a8a-8955-48818b3b42ed.png)

# %% [markdown]
#     To rename the table Users columns I used the object explorer and expanded the table user and under columns the column names will data types will show, then right click and rename. The nw column names can be shown below as a result table from querying the table.

# %% [markdown]
# ![image.png](attachment:e4a7503a-57c3-4f72-88ef-43f4a40fff13.png)

# %% [markdown]
#     The query before SELECT which is the DELETE clause allows us to delete the entire row where column1 is 'Region',and then followed the renaming of columns and the table is now standard.

# %% [markdown]
# <br>

# %% [markdown]
# ### 3. Business Questions
#
#     a. What is the business profit evolution?
#     b. What is the most profitable Product Category by Year?
#     c. Conduct a Revenue Analysis by City and Product Name.
#     d. How much sales were lost on returned products, by category and state over the years, most returned product?
#     e. What is the average order turnaround times in 2013 by state?
#     f. Who is our most loyal customers over the period?
#     g. Show customer segment profitability over time.
#     h. What is the most profitable region and manager by over the period?

# %% [markdown]
# <br>

# %% [markdown]
# ### 4. Business Solutions

# %% [markdown]
#     a. What is the business profit evolution?

# %% [markdown]
# ![image.png](attachment:b53a16cd-a1b5-40ba-941d-758d36eb00e5.png)

# %% [markdown]
#     The most profitable year to the business was in 2013 where the business made a profit of $450,106 followed by 2012 the preceding year with $354,587. The least profitable year for the business was in 2014 where the business profit dipped to an all period low of $2,762. What could have impacted the business in 2014 to perform so badly? Lets look at the cost lines for the business.

# %% [markdown]
#     i. Shipping Cost of the Business
#
# ![image.png](attachment:452c2ab6-0163-4c1b-9a18-31d52ba94cdd.png)

# %% [markdown]
#     From the shipping costs it shows that year 2014 had the least shipping cost of all the trading years, however these costs could be high relative to the revenue of the business in that specific year. We perform a Revenue analysis to check for the revenue over the period.

# %% [markdown]
#     ii. Revenue Analysis by trading year
#
# ![image.png](attachment:6bec435c-dc76-46b9-873a-b7b0fac0fd57.png)

# %% [markdown]
#     Trading year 2014 had a relatively lower revenue during the 5 year period, this is the reason why the profit is slim in the year. Revenue is a function of Price and Volume which means that either average price was very low or the business didn't realise substantive volume in the year in question. The business could also have been affected bt returns in the year which is the next section that we look at to firm up the causes for such a huge Revenue and Profit drops in 2014.

# %% [markdown]
#     ii. Volume Analysis by trading year
#
# ![image.png](attachment:b20dcf42-8fda-4523-adb6-060bda0305a2.png)

# %% [markdown]
#     It is very clear from the above that the business did not do justice in pushing the volumes in 2014, where the volumes have declined by 99.7% from prior year. This is a worrisome trend in business, on a brighter kpi the business managed to stay afloat recording a positive operating profit.

# %% [markdown]
# <br>

# %% [markdown]
#     b. What is the most profitable Product Category by Year?

# %% [markdown]
# ![image.png](attachment:7aa973e1-ba6d-4953-a592-5d73f076266f.png)

# %% [markdown]
#     We make use of CTE's to query the profit of each Product Category by Year for the 5 year period. In the year 2010 Office supplies was the most profitable category to sell with Furniture being the least the trading year. Furniture improved to being the most lucrative business to sell after Technology which made a profit of $173,199 in the year 2011. Technology proved to be a viable business in the following year of 2012 raking in a profit of $211,491 making up 60% of the business's profit. In the same year office supplies business improved to close the year as the second best perfoming business from a ditch in the trading year of 2011. Office Supplies unit in 2013 took a turn from a mediocre perfomance in 2012 and emerged as the best improved business unit in 2013 having grown by 139%, Technology maintained its positive trajectory recording a 11% profit growth from the previous trading year. The year 2014 overall business was subdued, however Office Supplies maintained a positve profit together with the Technology business, both businesses dropped massively in profit by margins of 99%.

# %% [markdown]
# <br>

# %% [markdown]
#     c. Conduct a Revenue Analysis by State and Product Sub Category.

# %% [markdown]
# ![image.png](attachment:beb46324-479d-4999-801b-f586ac7c755f.png)

# %% [markdown]
#     The list above shows the evolution of Revenue across States and Product Sub Category over the 5 year period.
#
#
#     Bookcases in  California brought the highest Revenue in the year 2012 within the 5 year trading period of the company. In 2010 the State of California recorded the highest Revenue coming from the Office Machine sub category. California also dominated in the year 2013 with Office Machines selling in $65,113.

# %% [markdown]
#     Further to the above analysis below is an analysis of the States perfomance over all categories, showing the dominance of the State of California from 2010 up until the year 2013 which recorded an all time highest Revenue of $325,395 in its 4 year reign as the state with the highest proceeds from sales. New York carried the business in the devastating year of 2014 where business was on the downside in all the categories and recorded a revenue of $9,641 marking the lowest sales in the 5 year history of the company.

# %% [markdown]
# ![image.png](attachment:e303ee43-cce6-435c-b85c-d7622a56e5f9.png)

# %% [markdown]
# <br>

# %% [markdown]
#     d. How much sales were lost on returned products, by category and state over the years, most returned product?

# %% [markdown]
# ![image.png](attachment:574675f5-eab6-471e-95cd-5a2990feadf7.png)

# %% [markdown]
#     From the query above the results show the lost sales due to returned products the years. Key to note is that there were no returns in the trading year of 2014. in 2011 and 2012 Furniture contributed notably to the lost business due to returned product.

# %% [markdown]
#     The query below gives us an insight into the months with the highest returns over the 4 years the company had returns, it is clear that September consecutively over 2011 and 2012 had the highest loss of sales due to returns.

# %% [markdown]
# ![image.png](attachment:92db4e7d-8710-4c3e-87f3-7a67d46a0df5.png)

# %% [markdown]
#     The query and results below should help the business in getiing intouch with customers that returned product and understand the customer complaints if any to ensure customer satisfaction, business continuity, reduction of waste and shipping costs.
#
# ![image.png](attachment:c7dc6b1d-ba9f-411f-aba9-51d24cc0b5d1.png)

# %% [markdown]
# <br>

# %% [markdown]
#     e. What is the average order turnaround time in 2014 by state?

# %% [markdown]
#     Average order delivery times (days) over the years.
#
# ![image.png](attachment:a769f4fa-4702-4584-807e-8118bfbb3e3b.png)

# %% [markdown]
#     Average cost of delivery over the years
# ![image.png](attachment:d092fa78-bc35-43e5-bf6f-3321f086364d.png)

# %% [markdown]
#     As shown in the query and result below it took more days to deliver in 2014 by Express Air than any of the shipping modes over the years. This turnaround time is way out of range and above the 5 year average of 2 days. In the same year it is also clear that it took more time to fulfill the orders than any other year and shipping mode in comparison to 2014. This analysis gives an insight into the poor business metrics recorded in 2014, orders took more time than usual to be fully processed which means less orders were fulfilled hence very low revenue recorded in this year.
#
# ![image.png](attachment:d2c9f30a-3869-4c90-9431-2f5a42ade946.png)

# %% [markdown]
#     Looking at the shipping costs the trend discovered in the delivery days seems to be inherent also in the shipping cost of the 3 different shipping modes over the years. The delivery truck mode costed more on average in 2014 with a cost of $62.72 which is on the upside compared to the company average shiping cost with the same mode of $45.19, this can be attributed to low sales orders in the period of the year. Express Air and Regular Air models of delivery are quite okay in 2014 ranging within the company average costs.
#
#     In future it is important to consider a balance between these models when the volumes are as low as 2014 sales.
#
# ![image.png](attachment:8d7d3a6f-e0a7-4b8c-a98d-d361a7f79c75.png)

# %% [markdown]
# <br>

# %% [markdown]
#     Only 3 states were deliverrd products in 2014, it took 17 days to deliver product in Florida using a Delivery ruck and 19 days using Regular Air. In New York the delivery truck took an average of 2 days which is the standard time and delayed by an average of 17 days using Express Air. In 2014 delivering with Express seemed to be problematic. Illinois orders were delivered in time.
#
# ![image.png](attachment:32543a3a-0a71-4e5c-94d1-4cac95bfa425.png)

# %% [markdown]
# <br>

# %% [markdown]
#     f. Who is our most loyal customers over the period?

# %% [markdown]
#     The business's most loyal customers are those that have ordered for more than 11 times over the 5 year operational period of the business. From below we see that Louis Parrish ordered 17 times during the period and Andrew Gonzalez came second with 16 times order doing business with the company.
#
# ![image.png](attachment:8b2fa73f-0aba-4fcc-b9af-d64002282c50.png)

# %% [markdown]
#     The High Net Value customers to the business are given in the results table as the top 10 customers with high sales during the 5 year period.
#
# ![image.png](attachment:11ac37a2-48a7-465e-87a9-d534099acea9.png)

# %% [markdown]
#     It is quite important to understand the sales lost due to returned product by customers. Below query and results show the customers who returned products and the respective value of the returned products.
#
#
# ![image.png](attachment:1320848b-f56a-4089-a290-4d4bb615268c.png)

# %% [markdown]
# <br>

# %% [markdown]
#     g. Show customer segment profitability over time.

# %% [markdown]
#     The most profitable Customer segement is the Corporate segment with sales worth $493,985 over the 5 year period. The least profitable business is the consumer business unit with a total of $201,102.
#
# ![image.png](attachment:965c5246-7eed-4c86-b5c1-cc4ea186f165.png)

# %% [markdown]
# <br>

# %% [markdown]
#     h. What is the most profitable region and manager by over the period?

# %% [markdown]
#     The most profitable region to the business over the past 5 years is the Central Region Managed by Chris and the least performing in terms of profit is the Southern Region which is managed by Sam.
#
# ![image.png](attachment:87b66a7e-295a-432f-a94f-0dbfc46ca89a.png)

# %% [markdown]
# <br>

# %% [markdown]
# ### 5. Conclusion
#
#     It has been an interesting querying session with the use of functions from Aggregate functions to window functions, the WHERE clause, ORDER BY clause and obvious the SELECT and FROM CLAUSE. The data can be further analyzed to draw much moe insights, however in this project the aim was to get a glimpse of the data using SQL commanrds which I am sure we have done justice to.
